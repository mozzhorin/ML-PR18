# %%
# coding: utf-8

import numpy as np
import time

import torch
import torch.nn as nn
import torch.nn.functional as F

from airbus_dataloader import *
from airbus_train_val_functions import *


class Net2(nn.Module):
    def __init__(self):
        super(Net2, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16*45*45, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16*45*45)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class CNN_32_x4(nn.Module):
    def __init__(self, num_classes):
        super(CNN_32_x4, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 32, 5) # input features, output features, kernel size
        self.act1 = nn.ReLU()
        self.mp1 = nn.MaxPool2d(2, 2) # kernel size, stride
        
        self.conv2 = nn.Conv2d(32, 64, 5) # input features, output features, kernel size
        self.act2 = nn.ReLU()
        self.mp2 = nn.MaxPool2d(2, 2) # kernel size, stride
        
        self.fc = nn.Linear(64*45*45, num_classes) # 4x4 is the remaining spatial resolution here

    def forward(self, x):
        x = self.mp1(self.act1(self.conv1(x)))
        x = self.mp2(self.act2(self.conv2(x)))
        # The view flattens the output to a vector (the representation needed by the classifier)
        x = x.view(-1, 64*45*45)
        x = self.fc(x)
        return x
    
class CNN_8_x4(nn.Module):
    def __init__(self, num_classes):
        super(CNN_8_x4, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 8, 5) # input features, output features, kernel size
        self.act1 = nn.ReLU()
        self.mp1 = nn.MaxPool2d(2, 2) # kernel size, stride
        
        self.conv2 = nn.Conv2d(8, 16, 5) # input features, output features, kernel size
        self.act2 = nn.ReLU()
        self.mp2 = nn.MaxPool2d(2, 2) # kernel size, stride
        
        self.fc = nn.Linear(16*45*45, num_classes) # 4x4 is the remaining spatial resolution here

    def forward(self, x):
        x = self.mp1(self.act1(self.conv1(x)))
        x = self.mp2(self.act2(self.conv2(x)))
        # The view flattens the output to a vector (the representation needed by the classifier)
        x = x.view(-1, 16*45*45)
        x = self.fc(x)
        return x


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
is_gpu = torch.cuda.is_available()
batch_size = 2
workers = 4
path = '../airbus/'
aug=False
resize_factor=4
empty_frac=1
test_size=0.1
    
dataset = AirbusDS(torch.cuda.is_available(), batch_size, workers, path, aug, resize_factor, empty_frac, test_size)


# Define optimizer and loss function (criterion)
#model = CNN_8_x4(2).to(device)
model = torch.load('CNN_8_x4.model', map_location='cpu').to(device)
criterion = nn.CrossEntropyLoss().to(device)

# we can use advanced stochastic gradient descent algorithms 
# with regularization (weight-decay) or momentum
optimizer = torch.optim.SGD(model.parameters(), lr=0.001,
                            momentum=0.9,
                            weight_decay=5e-4)
# Out:
# /home/mo/git/ML-PR18/airbus_dataloader.py:246: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   train_ids['file_size_kb'] = train_ids['ImageId'].map(lambda c_img_id: os.stat(os.path.join(self.path_train, c_img_id)).st_size/1024)
# /home/mo/anaconda3/lib/python3.6/site-packages/torch/serialization.py:391: UserWarning: Couldn't retrieve source code for container of type CNN_8_x4. It won't be checked for correctness upon loading.
#   "type " + container_type.__name__ + ". It won't be checked "

# %%
predict(dataset.test_loader, model, device, treshold=0.5)
# Out:
# START PREDICTIONS 2018-09-29 13:26:19
# Process Process-3:
# Process Process-1:
# Process Process-2:
# Process Process-4:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 258, in _bootstrap
#     self.run()
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/git/ML-PR18/airbus_dataloader.py", line 166, in __getitem__
#     return self.transform(image), ImageId
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in _worker_loop
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 106, in <listcomp>
#     samples = collate_fn([dataset[i] for i in batch_indices])
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/home/mo/git/ML-PR18/airbus_dataloader.py", line 166, in __getitem__
#     return self.transform(image), ImageId
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 175, in __call__
#     return F.resize(img, self.size, self.interpolation)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 187, in default_collate
#     return [default_collate(samples) for samples in transposed]
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 175, in __call__
#     return F.resize(img, self.size, self.interpolation)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/functional.py", line 206, in resize
#     return img.resize(size[::-1], interpolation)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/functional.py", line 206, in resize
#     return img.resize(size[::-1], interpolation)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1745, in resize
#     self.load()
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 187, in <listcomp>
#     return [default_collate(samples) for samples in transposed]
#   File "/home/mo/git/ML-PR18/airbus_dataloader.py", line 166, in __getitem__
#     return self.transform(image), ImageId
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 164, in default_collate
#     return torch.stack(batch, 0, out=out)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1745, in resize
#     self.load()
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 236, in load
#     n, err_code = decoder.decode(b)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 49, in __call__
#     img = t(img)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 236, in load
#     n, err_code = decoder.decode(b)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/transforms.py", line 175, in __call__
#     return F.resize(img, self.size, self.interpolation)
# KeyboardInterrupt
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torchvision/transforms/functional.py", line 206, in resize
#     return img.resize(size[::-1], interpolation)
# KeyboardInterrupt
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/PIL/Image.py", line 1745, in resize
#     self.load()
# KeyboardInterrupt
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/PIL/ImageFile.py", line 236, in load
#     n, err_code = decoder.decode(b)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-c325241ed5d9>", line 1, in <module>
#     predict(dataset.test_loader, model, device, treshold=0.5)
#   File "/home/mo/git/ML-PR18/airbus_train_val_functions.py", line 232, in predict
#     for i, data in enumerate(test_loader):
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 330, in __next__
#     idx, batch = self._get_batch()
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 309, in _get_batch
#     return self.data_queue.get()
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/mo/anaconda3/lib/python3.6/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 227, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 24031) exited unexpectedly with exit code 1. Details are lost due to multiprocessing. Rerunning with num_workers=0 may give better error trace.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/mo/anaconda3/lib/python3.6/inspect.py", line 1483, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/mo/anaconda3/lib/python3.6/inspect.py", line 1441, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/mo/anaconda3/lib/python3.6/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/mo/anaconda3/lib/python3.6/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/home/mo/anaconda3/lib/python3.6/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/home/mo/anaconda3/lib/python3.6/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/home/mo/anaconda3/lib/python3.6/genericpath.py", line 19, in exists
#     os.stat(path)
#   File "/home/mo/anaconda3/lib/python3.6/site-packages/torch/utils/data/dataloader.py", line 227, in handler
#     _error_if_any_worker_fails()
# SystemError: <built-in function _error_if_any_worker_fails> returned a result with an error set
# ---------------------------------------------------------------------------
